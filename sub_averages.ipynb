# %%
import glob
import pandas as pd
from scipy.io import loadmat
import numpy as np
import matplotlib.pyplot as plt

# %%
col_list = ['Npoints', 
            'lapse1',
            'lapse2', 
            'deckchoice', 
            'RT1', 
            'RT2', 
            'choice_onset', 
            'press1_onset', 
            'info_onset', 
            'partner_onset', 
            'press2_onset', 
            'aff_onset', 
            'fix1_list', 
            'fix2_list', 
            'fix3_list', 
            'fix4_list', 
            'soc_win', 
            'block', 
            'duration', 
            'frequency', 
            'stimaff', 
            'stiminf', 
            'point_total', 
            'word', 
            'rating', 
            'is_catch', 
            'partner', 
            'highval_count']
file_list = glob.glob('../data/behavioral/raw/reward-signals/data/10*/*[0-4].mat')

# %%
sub_list = glob.glob('../data/behavioral/raw/reward-signals/data/10*/')

subject_ws = []
subject_ls = []


for i in sub_list:
    mat_ws = []
    mat_ls = []
    for mat_file in glob.glob(i+('*feed*[0-4].mat')):
        df = pd.DataFrame([[row.flat[0] for row in line] for line in loadmat(mat_file)['data'][0]], columns=col_list)
        
        
        dc_1 = df.loc[df['deckchoice'] == 1]  
        print(dc_1.iloc[7:8])
        
        
        for i,row in dc_1.iterrows():
            if i == 0:
                pass
            else:
                print(i)
                previous = (dc_1.iloc[i-1:i], row)
                earlier = (dc_1.iloc[i-2:i],row)    
                
        choice_1_wins = dc_1['soc_win'].sum()

        
        dc_2 = df.loc[df['deckchoice'] == 2]
        choice_2_wins = dc_2['soc_win'].sum()
# Out:
# Empty DataFrame
# Columns: [Npoints, lapse1, lapse2, deckchoice, RT1, RT2, choice_onset, press1_onset, info_onset, partner_onset, press2_onset, aff_onset, fix1_list, fix2_list, fix3_list, fix4_list, soc_win, block, duration, frequency, stimaff, stiminf, point_total, word, rating, is_catch, partner, highval_count]
# Index: []
#
# [0 rows x 28 columns]
# 1
# 4
# 7
# 10
# 38
#    Npoints  lapse1  lapse2  deckchoice       RT1       RT2  choice_onset  \
# 7       45       0       0           1  0.548334  1.814274    143.278598
#
#    press1_onset  info_onset  partner_onset  ...  duration  frequency  stimaff  \
# 7    143.844859  147.528863     153.761337  ...      1750         55        0
#
#    stiminf  point_total       word  rating  is_catch  partner  highval_count
# 7        1          838  irritable     0.0         0        1             47
#
# [1 rows x 28 columns]
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 14
# 16
# 18
# ...
